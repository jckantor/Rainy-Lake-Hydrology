# %%
# Display graphics inline with the notebook
# %matplotlib notebook

# Standard Python modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import datetime
import requests

# Modules to display images and data tables
from IPython.display import Image
from IPython.core.display import display

WSC_STATIONS = pd.read_pickle('../data/WSC_STATIONS')
WSC_LEVELS = pd.read_pickle('../data/WSC_LEVELS')
WSC_FLOWS = pd.read_pickle('../data/WSC_FLOWS')

# %%
WSC_FLOWS.columns
# Out:
# Index(['05PA001', '05PA006', '05PA012', '05PB001', '05PB003', '05PB004',
#        '05PB009', '05PB014', '05PB015', '05PB018', '05PB019', '05PB020',
#        '05PB021', '05PB022', '05PC009', '05PC010', '05PC016', '05PC018',
#        '05PC019', '05PC022'],
#       dtype='object')

# %%
WSC_LEVELS['05PA012'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
RR = pd.read_pickle('../data/RR.pkl').plot()

# %%
RL = pd.read_pickle('../data/RR.pkl').plot()
